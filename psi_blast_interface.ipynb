# %% [markdown]
# ## Runing psi-blast
# This script runs psi-blast search by random protein of given cog in cogdb

# %%
# importing all modules and settings
import os
import pandas as pd
import numpy as np
from Bio.Blast.Applications import NcbipsiblastCommandline
from Bio.Align.Applications import MuscleCommandline
from Bio import Entrez
from Bio import SearchIO
from Bio import SeqIO
from Bio.Blast import NCBIXML
from collections import defaultdict
import pprint


Entrez.email = "isnicsi@gmail.com"
Entrez.api_key = "86bf08a1f3f3f3135f053107c3fa228c9508"

# These are the COGs suggested by correlation analysis
cogs = [
    "COG1563",
    "COG1269",
    "COG1827",
    "COG4945",
    "COG0636",
    "COG2426",
    "COG1906",
    "COG4769",
    "COG1822",
    "COG4720",
    "COG1852",
    "COG2456",
    "COG1883",
    "COG4708",
    "COG1750",
    "COG4035",
    "COG4042",
    "COG1784",
    "COG2034",
    "COG4039",
    "COG4038",
    "COG4907",
    "COG4040",
    "COG4037",
    "COG4036",
    "COG4041",
    "COG4078",
    "COG1933",
    "COG0650",
    "COG4059",
    "COG4060",
    "COG2245",
    "COG4061",
    "COG0170",
    "COG1456",
    "COG1800",
    "COG3872",
    "COG1284",
    "COG4743",
    "COG1916",
    "COG5306",
    "COG2035",
    "COG1967",
    "COG1340",
    "COG3641",
    "COG1422",
    "COG4026",
    "COG4658",
    "COG2461",
    "COG3889",
    "COG4660",
    "COG4657",
    "COG4025",
    "COG1811",
    "COG1963",
    "COG3086",
    "COG1361",
    "COG3356",
    "COG2155",
    "COG3601",
    "COG1824",
    "COG1480",
    "COG0619",
    "COG3371",
    "COG1955",
    "COG2431",
    "COG5625",
    "COG3314",
    "COG2512",
    "COG2510",
    "COG4640",
    "COG1863",
    "COG3815",
    "COG4046",
    "COG1930",
    "COG4603",
    "COG1470",
    "COG1079",
    "COG2383",
    "COG3330",
    "COG4827",
    "COG1624",
    "COG0530",
    "COG1006",
    "COG0310",
    "COG4346",
    "COG4089",
    "COG2059",
    "COG4906",
    "COG1347",
    "COG1814"
]  # specify cogs
found_cogs = defaultdict(set) # here all found cogs will be stored
psi_iter = 10
evalt = 1e-3
max_seqs = 500

# %%
# defining necessary functions
def fetch_seq(yp_id, label=""):    
    with Entrez.efetch(db="protein", rettype="fasta", retmode="text", id=yp_id) as handle:
        seq = SeqIO.read(handle, "fasta")
        seq.id += "_" + label
        return seq


def rename_seq(cogdb, seq):
    try:
        newid = cogdb.loc[seq.id.split("|")[-1]][6]
    except KeyError:
        newid = "0"
    if isinstance(newid, pd.Series):
        newid = "_".join(newid)
    found_cogs[cog].add(newid)
    seq.id = newid
    return seq

    
def rename_rec(cogdb, rec):
    return list(map(lambda x: rename_seq(cogdb, x[0].hit), rec))

# %%
# loading COG database
cogdb = pd.read_csv('/home/ilbumi/united_data_lib/cog/cog2003-2014.csv', header=None, index_col=0)

# %%
# perform psi-blast
for cog in cogs:
    print("Processing "+cog)
    sample = list(map(lambda x: fetch_seq(x, label=cog), cogdb[cogdb[6]==cog].sample(1).index))
    os.makedirs(cog, exist_ok=True)
    SeqIO.write(sample, "{}/{}_query.fasta".format(cog, cog), "fasta")
    print("\tStarting PSI-BLAST...")
    cline = NcbipsiblastCommandline(
        query="{}/{}_query.fasta".format(cog, cog),
        db="711proteomes",
        outfmt=5,
        out="{}/{}_results.xml".format(cog, cog),
        evalue=evalt,
        max_target_seqs=1000,
        num_iterations=psi_iter,
        out_pssm="{}/{}_pssm.txt".format(cog, cog),
        num_threads=3
    )
    cline()
    print("\tPSI-BLAST done!")
    
    records = list(SearchIO.parse("{}/{}_results.xml".format(cog, cog), "blast-xml"))
    results = rename_rec(cogdb, records[-1])
    SeqIO.write(results, "results/{}_results.fasta".format(cog, cog), "fasta")

# %%
# printing found COGs
names = pd.read_table("/home/ilbumi/united_data_lib/cog/cognames2003-2014.tab", index_col=0)


def name_cogs(s):
    res = []
    for cog in s:
        if cog == '0':
            sr = ("UnCOGged")
        elif "_" in cog:
            sr = tuple(map(lambda x: names.loc[x]["name"], cog.split("_")))
        else:
            sr = (names.loc[cog]["name"])
        res.append(sr)
    return list(zip(s, res))
 
    
for k, v in found_cogs.items():
    print(k)
    found_names = name_cogs(v)
    for name in found_names:
        print("\t{}\t{}".format(*name))
# Out:
# /home/ilbumi/anaconda3/envs/sci/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# COG1563
# 	COG2111	Multisubunit Na+/H+ antiporter, MnhB subunit
# 	COG1563	Uncharacterized MnhB-related membrane protein
# 	COG1009_COG2111_COG2111	('NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit')
# 	COG0839	NADH:ubiquinone oxidoreductase subunit 6 (chain J)
# 	COG1563_COG4623	('Uncharacterized MnhB-related membrane protein', 'Membrane-bound lytic murein transglycosylase MltF')
# 	COG0834	ABC-type amino acid transport/signal transduction system, periplasmic component/domain
# 	COG0839_COG0839	('NADH:ubiquinone oxidoreductase subunit 6 (chain J)', 'NADH:ubiquinone oxidoreductase subunit 6 (chain J)')
# 	COG1009_COG2111	('NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit')
# COG1269
# 	COG0004_COG3706	('Ammonia channel protein AmtB', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain')
# 	COG0004_COG2202_COG3829_COG5000_COG5001	('Ammonia channel protein AmtB', 'PAS domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0004_COG5001_COG5002	('Ammonia channel protein AmtB', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain', 'Signal transduction histidine kinase')
# 	COG0004_COG2114_COG5002	('Ammonia channel protein AmtB', 'Adenylate cyclase, class 3', 'Signal transduction histidine kinase')
# 	COG0004_COG0745_COG2205	('Ammonia channel protein AmtB', 'DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'K+-sensing histidine kinase KdpD')
# 	COG0004_COG0784_COG0784_COG2198_COG5002	('Ammonia channel protein AmtB', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Signal transduction histidine kinase')
# 	COG0004_COG5001	('Ammonia channel protein AmtB', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0004_COG0784_COG0784_COG2202_COG2203_COG2205_COG5444	('Ammonia channel protein AmtB', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'GAF domain', 'K+-sensing histidine kinase KdpD', 'Predicted ribonuclease, toxin component of the YeeF-YezG toxin-antitoxin module')
# 	COG0004	Ammonia channel protein AmtB
# 	COG0004_COG3852_COG5001	('Ammonia channel protein AmtB', 'Signal transduction histidine kinase, nitrogen specific', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0004_COG5000_COG5001	('Ammonia channel protein AmtB', 'Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0004_COG4585	('Ammonia channel protein AmtB', 'Signal transduction histidine kinase')
# 	COG0004_COG2199	('Ammonia channel protein AmtB', 'GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants')
# 	COG0004_COG2114	('Ammonia channel protein AmtB', 'Adenylate cyclase, class 3')
# 	COG0004_COG0347	('Ammonia channel protein AmtB', 'Nitrogen regulatory protein PII')
# 	COG0004_COG4191	('Ammonia channel protein AmtB', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0004_COG2202_COG5001	('Ammonia channel protein AmtB', 'PAS domain', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0004_COG0784_COG2205	('Ammonia channel protein AmtB', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD')
# 	COG1269	Archaeal/vacuolar-type H+-ATPase subunit I/STV1
# 	COG0004_COG2205	('Ammonia channel protein AmtB', 'K+-sensing histidine kinase KdpD')
# 	COG1196_COG1269	('Chromosome segregation ATPase', 'Archaeal/vacuolar-type H+-ATPase subunit I/STV1')
# COG1827
# 	COG1349	DNA-binding transcriptional regulator of sugar metabolism, DeoR/GlpR family
# COG4945
# 	COG0366_COG4945_COG5492	('Glycosidase', 'Carbohydrate-binding DOMON domain', 'Uncharacterized conserved protein YjdB, contains Ig-like domain')
# 	COG1449_COG4945_COG4945	('Alpha-amylase/alpha-mannosidase, GH57 family', 'Carbohydrate-binding DOMON domain', 'Carbohydrate-binding DOMON domain')
# 	COG3387_COG4945	('Glucoamylase (glucan-1,4-alpha-glucosidase), GH15 family', 'Carbohydrate-binding DOMON domain')
# 	COG4945	Carbohydrate-binding DOMON domain
# 	COG0366_COG4945_COG4945	('Glycosidase', 'Carbohydrate-binding DOMON domain', 'Carbohydrate-binding DOMON domain')
# 	COG1073	Fermentation-respiration switch protein FrsA, has esterase activity, DUF1100 family
# 	COG0296_COG4945	('1,4-alpha-glucan branching enzyme', 'Carbohydrate-binding DOMON domain')
# 	COG3867_COG4945	('Arabinogalactan endo-1,4-beta-galactosidase', 'Carbohydrate-binding DOMON domain')
# 	COG1449_COG4945	('Alpha-amylase/alpha-mannosidase, GH57 family', 'Carbohydrate-binding DOMON domain')
# 	COG4945_COG4945	('Carbohydrate-binding DOMON domain', 'Carbohydrate-binding DOMON domain')
# 	COG0296_COG0296_COG4945	('1,4-alpha-glucan branching enzyme', '1,4-alpha-glucan branching enzyme', 'Carbohydrate-binding DOMON domain')
# 	COG0366_COG4945	('Glycosidase', 'Carbohydrate-binding DOMON domain')
# 	0	UnCOGged
# COG0636
# 	COG0636	FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K
# 	COG0636_COG0636_COG0636	('FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K', 'FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K', 'FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K')
# 	0	UnCOGged
# 	COG0636_COG0636	('FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K', 'FoF1-type ATP synthase, membrane subunit c/Archaeal/vacuolar-type H+-ATPase, subunit K')
# COG2426
# 	COG2426	Uncharacterized membrane protein
# 	0	UnCOGged
# COG1906
# 	COG4664	TRAP-type mannitol/chloroaromatic compound transport system, large permease component
# 	COG1593_COG1638	('TRAP-type C4-dicarboxylate transport system, large permease component', 'TRAP-type C4-dicarboxylate transport system, periplasmic component')
# 	COG4664_COG4665	('TRAP-type mannitol/chloroaromatic compound transport system, large permease component', 'TRAP-type mannitol/chloroaromatic compound transport system, small permease component')
# 	COG1593_COG1593	('TRAP-type C4-dicarboxylate transport system, large permease component', 'TRAP-type C4-dicarboxylate transport system, large permease component')
# 	COG1593_COG3090	('TRAP-type C4-dicarboxylate transport system, large permease component', 'TRAP-type C4-dicarboxylate transport system, small permease component')
# 	COG1593_COG4665	('TRAP-type C4-dicarboxylate transport system, large permease component', 'TRAP-type mannitol/chloroaromatic compound transport system, small permease component')
# 	COG1593	TRAP-type C4-dicarboxylate transport system, large permease component
# COG4769
# 	COG4769_COG5341	('Uncharacterized membrane protein', 'Uncharacterized protein')
# 	COG0619_COG4769	('Energy-coupling factor transporter transmembrane protein EcfT', 'Uncharacterized membrane protein')
# 	COG4769	Uncharacterized membrane protein
# COG1822
# 	COG1822	Uncharacterized membrane protein
# COG4720
# 	COG0395_COG3829_COG5001_COG5002	('ABC-type glycerol-3-phosphate transport system, permease component', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain', 'Signal transduction histidine kinase')
# 	COG2202_COG3275_COG5001	('PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0745_COG0784_COG2198_COG2205_COG3829_COG3850	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase, nitrate/nitrite-specific')
# 	0	UnCOGged
# 	COG3275_COG3275	('Sensor histidine kinase, LytS/YehU family', 'Sensor histidine kinase, LytS/YehU family')
# 	COG1122_COG1122_COG4720	('Energy-coupling factor transporter ATP-binding protein EcfA2', 'Energy-coupling factor transporter ATP-binding protein EcfA2', 'Uncharacterized membrane protein')
# 	COG0784_COG2202_COG2203_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2208	Serine phosphatase RsbU, regulator of sigma subunit
# 	COG0745_COG2202_COG2205_COG4191	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0697_COG0784_COG2198_COG5000_COG5002	('Permease of the drug/metabolite transporter (DMT) superfamily', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation', 'Signal transduction histidine kinase')
# 	COG2202_COG2202_COG5002_COG5002	('PAS domain', 'PAS domain', 'Signal transduction histidine kinase', 'Signal transduction histidine kinase')
# 	COG1914_COG3275	('Mn2+ and Fe2+ transporters of the NRAMP family', 'Sensor histidine kinase, LytS/YehU family')
# 	COG3859	Thiamine transporter ThiT
# 	COG3275_COG3706	('Sensor histidine kinase, LytS/YehU family', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain')
# 	COG0784_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2205_COG3275	('K+-sensing histidine kinase KdpD', 'Sensor histidine kinase, LytS/YehU family')
# 	COG5002	Signal transduction histidine kinase
# 	COG2202_COG2202_COG5001	('PAS domain', 'PAS domain', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG3850_COG4191	('Signal transduction histidine kinase, nitrate/nitrite-specific', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG3300_COG5001	('MHYT domain, NO-binding membrane sensor', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0697_COG4172	('Permease of the drug/metabolite transporter (DMT) superfamily', 'ABC-type microcin C transport system, duplicated ATPase component YejF')
# 	COG0784_COG2198_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'K+-sensing histidine kinase KdpD')
# 	COG3601	Riboflavin transporter FmnP
# 	COG1080_COG1925_COG2213_COG4668	('Phosphoenolpyruvate-protein kinase (PTS system EI component in bacteria)', 'Phosphotransferase system, HPr and related phosphotransfer proteins', 'Phosphotransferase system, mannitol-specific IIBC component', 'Mannitol/fructose-specific phosphotransferase system, IIA domain')
# 	COG5001	Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain
# 	COG2199	GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants
# 	COG4191_COG5002	('Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase')
# 	COG0745_COG2202_COG2202_COG3275_COG3852	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'PAS domain', 'PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG2208_COG2770_COG4720	('Serine phosphatase RsbU, regulator of sigma subunit', 'HAMP domain', 'Uncharacterized membrane protein')
# 	COG0784_COG0784_COG2198_COG2202_COG2205_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0784_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0310_COG2202_COG2202_COG3829_COG4251	('ABC-type Co2+ transport system, permease component', 'PAS domain', 'PAS domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG2199_COG2206_COG3275	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family')
# 	COG0784_COG2198_COG5002	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Signal transduction histidine kinase')
# 	COG2205_COG3829_COG3829	('K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG3706	Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain
# 	COG1480	Membrane-associated HD superfamily phosphohydrolase
# 	COG2199_COG2206	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)')
# 	COG0784_COG4191_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG4732	Predicted membrane protein
# 	COG3706_COG3829	('Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG2205	K+-sensing histidine kinase KdpD
# 	COG0642_COG0784_COG2202	('Signal transduction histidine kinase', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain')
# 	COG0784_COG2202_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD')
# 	COG0755_COG1333	('ABC-type transport system involved in cytochrome c biogenesis, permease component', 'Cytochrome c biogenesis protein ResB')
# 	COG3275_COG3706_COG5002	('Sensor histidine kinase, LytS/YehU family', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Signal transduction histidine kinase')
# 	COG2203_COG3706_COG3829	('GAF domain', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG3290_COG3437	('Sensor histidine kinase regulating citrate/malate metabolism', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG4684	Uncharacterized membrane protein
# 	COG2208_COG3275	('Serine phosphatase RsbU, regulator of sigma subunit', 'Sensor histidine kinase, LytS/YehU family')
# 	COG4769	Uncharacterized membrane protein
# 	COG3275_COG3829_COG5002	('Sensor histidine kinase, LytS/YehU family', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase')
# 	COG3275_COG5001	('Sensor histidine kinase, LytS/YehU family', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0784_COG0784_COG2198_COG2202_COG2203_COG2205_COG3829_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'GAF domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG3829_COG4251	('Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG3437	Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains
# 	COG2203_COG3275_COG4251	('GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG5000	Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation
# 	COG0784_COG2205_COG3829	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG2202_COG2202_COG4251	('PAS domain', 'PAS domain', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG2206_COG3275_COG3292_COG3292	('HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family', 'Periplasmic ligand-binding sensor domain', 'Periplasmic ligand-binding sensor domain')
# 	COG0619_COG1122_COG1122	('Energy-coupling factor transporter transmembrane protein EcfT', 'Energy-coupling factor transporter ATP-binding protein EcfA2', 'Energy-coupling factor transporter ATP-binding protein EcfA2')
# 	COG4191_COG4251	('Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG0784_COG2197_COG2202_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'DNA-binding response regulator, NarL/FixJ family, contains REC and HTH domains', 'PAS domain', 'K+-sensing histidine kinase KdpD')
# 	COG4191	Signal transduction histidine kinase regulating C4-dicarboxylate transport system
# 	COG2204_COG2461_COG3275_COG4191	('DNA-binding transcriptional response regulator, NtrC family, contains REC, AAA-type ATPase, and a Fis-type DNA-binding domains', 'Uncharacterized conserved protein, DUF438 domain, may contain hemerythrin domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2199_COG2202	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'PAS domain')
# 	COG0784_COG2205_COG3275	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD', 'Sensor histidine kinase, LytS/YehU family')
# 	COG2202_COG3275_COG5002	('PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase')
# 	COG3275_COG3437	('Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG3275_COG4191	('Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0745_COG0784_COG2198_COG2202_COG2205_COG4720	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Uncharacterized membrane protein')
# 	COG2203_COG2203_COG3275_COG3437	('GAF domain', 'GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG2206_COG3292_COG3292	('HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Periplasmic ligand-binding sensor domain', 'Periplasmic ligand-binding sensor domain')
# 	COG2199_COG3275_COG3437	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG0784_COG2202_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2202_COG3852	('PAS domain', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG2199_COG2202_COG2206_COG3275	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'PAS domain', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family')
# 	COG0784_COG2198_COG3275_COG4251	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Sensor histidine kinase, LytS/YehU family', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG4251	Bacteriophytochrome (light-regulated signal transduction histidine kinase)
# 	COG4720	Uncharacterized membrane protein
# 	COG2206	HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)
# 	COG1263_COG3829_COG3852	('Phosphotransferase system IIC components, glucose/maltose/N-acetylglucosamine-specific', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG0784_COG4191_COG5002	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase')
# 	COG3275	Sensor histidine kinase, LytS/YehU family
# COG1852
# 	COG0095	Lipoate-protein ligase A
# 	COG0142_COG1852	('Geranylgeranyl pyrophosphate synthase', 'Uncharacterized protein')
# 	COG0095_COG1852	('Lipoate-protein ligase A', 'Uncharacterized protein')
# 	COG1852	Uncharacterized protein
# 	COG0095_COG1880	('Lipoate-protein ligase A', 'CO dehydrogenase/acetyl-CoA synthase epsilon subunit')
# 	COG0095_COG1852_COG1880	('Lipoate-protein ligase A', 'Uncharacterized protein', 'CO dehydrogenase/acetyl-CoA synthase epsilon subunit')
# COG2456
# 	COG1216	Glycosyltransferase, GT2 family
# 	COG2456	Uncharacterized protein
# 	COG1215	Glycosyltransferase, catalytic subunit of cellulose synthase and poly-beta-1,6-N-acetylglucosamine synthase
# 	COG1216_COG2456	('Glycosyltransferase, GT2 family', 'Uncharacterized protein')
# 	COG0463	Glycosyltransferase involved in cell wall bisynthesis
# 	0	UnCOGged
# 	COG0463_COG2456	('Glycosyltransferase involved in cell wall bisynthesis', 'Uncharacterized protein')
# COG1883
# 	COG1883_COG1883	('Na+-transporting methylmalonyl-CoA/oxaloacetate decarboxylase, beta subunit', 'Na+-transporting methylmalonyl-CoA/oxaloacetate decarboxylase, beta subunit')
# 	COG0511_COG1883	('Biotin carboxyl carrier protein', 'Na+-transporting methylmalonyl-CoA/oxaloacetate decarboxylase, beta subunit')
# 	COG1883	Na+-transporting methylmalonyl-CoA/oxaloacetate decarboxylase, beta subunit
# COG4708
# 	COG4708	Uncharacterized membrane protein
# 	0	UnCOGged
# COG1750
# 	COG1067_COG4987	('Predicted ATP-dependent protease', 'ABC-type transport system involved in cytochrome bd biosynthesis, fused ATPase and permease components')
# 	COG0433_COG1067	('Archaeal DNA helicase HerA or a related bacterial ATPase, contains HAS-barrel and ATPase domains', 'Predicted ATP-dependent protease')
# 	COG1067_COG4372	('Predicted ATP-dependent protease', 'Uncharacterized conserved protein, contains DUF3084 domain')
# 	COG0466_COG1067	('ATP-dependent Lon protease, bacterial type', 'Predicted ATP-dependent protease')
# 	COG1067_COG4943	('Predicted ATP-dependent protease', 'Environmental sensor c-di-GMP phosphodiesterase, contains periplasmic CSS-motif sensor and cytoplasmic EAL domain')
# 	COG1067_COG1241	('Predicted ATP-dependent protease', 'DNA replicative helicase MCM subunit Mcm2, Cdc46/Mcm family')
# 	COG1067_COG1674	('Predicted ATP-dependent protease', 'DNA segregation ATPase FtsK/SpoIIIE and related proteins')
# 	COG1750	Predicted archaeal serine protease, S18 family
# 	COG0466_COG0466_COG3437	('ATP-dependent Lon protease, bacterial type', 'ATP-dependent Lon protease, bacterial type', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG1067_COG1221	('Predicted ATP-dependent protease', 'Transcriptional regulators containing an AAA-type ATPase domain and a DNA-binding domain')
# 	COG1067_COG1474	('Predicted ATP-dependent protease', 'Cdc6-related protein, AAA superfamily ATPase')
# 	COG0507_COG1067	('ATP-dependent exoDNAse (exonuclease V), alpha subunit, helicase superfamily I', 'Predicted ATP-dependent protease')
# 	COG0466	ATP-dependent Lon protease, bacterial type
# 	COG1014_COG1067	('Pyruvate:ferredoxin oxidoreductase or related 2-oxoacid:ferredoxin oxidoreductase, gamma subunit', 'Predicted ATP-dependent protease')
# 	COG1067_COG1222	('Predicted ATP-dependent protease', 'ATP-dependent 26S proteasome regulatory subunit')
# 	COG1067_COG1223	('Predicted ATP-dependent protease', 'Predicted ATPase, AAA+ superfamily')
# 	COG0419_COG1067	('DNA repair exonuclease SbcCD ATPase subunit', 'Predicted ATP-dependent protease')
# 	COG0630_COG1067	('Type IV secretory pathway ATPase VirB11/Archaellum biosynthesis ATPase', 'Predicted ATP-dependent protease')
# 	COG0470_COG1067	('DNA polymerase III, delta prime subunit', 'Predicted ATP-dependent protease')
# 	COG1067_COG1200	('Predicted ATP-dependent protease', 'RecG-like helicase')
# 	COG1067_COG3283	('Predicted ATP-dependent protease', 'Transcriptional regulator of aromatic amino acids metabolism')
# 	COG0457_COG0466	('Tetratricopeptide (TPR) repeat', 'ATP-dependent Lon protease, bacterial type')
# 	COG0465_COG1067	('ATP-dependent Zn proteases', 'Predicted ATP-dependent protease')
# 	COG0466_COG0466	('ATP-dependent Lon protease, bacterial type', 'ATP-dependent Lon protease, bacterial type')
# 	COG1067	Predicted ATP-dependent protease
# 	COG1067_COG2204	('Predicted ATP-dependent protease', 'DNA-binding transcriptional response regulator, NtrC family, contains REC, AAA-type ATPase, and a Fis-type DNA-binding domains')
# 	COG0210_COG1067	('Superfamily I DNA or RNA helicase', 'Predicted ATP-dependent protease')
# 	COG0714_COG1067_COG1372	('MoxR-like ATPase', 'Predicted ATP-dependent protease', 'Intein/homing endonuclease')
# 	COG0466_COG0466_COG4753	('ATP-dependent Lon protease, bacterial type', 'ATP-dependent Lon protease, bacterial type', 'Two-component response regulator, YesN/AraC family, consists of REC and AraC-type DNA-binding domains')
# 	COG1067_COG1638	('Predicted ATP-dependent protease', 'TRAP-type C4-dicarboxylate transport system, periplasmic component')
# 	COG1067_COG1484	('Predicted ATP-dependent protease', 'DNA replication protein DnaC')
# 	COG0714_COG1067	('MoxR-like ATPase', 'Predicted ATP-dependent protease')
# 	COG1067_COG3638	('Predicted ATP-dependent protease', 'ABC-type phosphate/phosphonate transport system, ATPase component')
# 	COG1067_COG3096	('Predicted ATP-dependent protease', 'Chromosome condensin MukBEF, ATPase and DNA-binding subunit MukB [Escherichia coli str. K-12 substr. MG1655')
# 	COG1067_COG1196	('Predicted ATP-dependent protease', 'Chromosome segregation ATPase')
# 	COG1067_COG4980	('Predicted ATP-dependent protease', 'Gas vesicle protein')
# 	COG1067_COG1340	('Predicted ATP-dependent protease', 'Uncharacterized coiled-coil protein, contains DUF342 domain')
# 	COG0606_COG1067	('Predicted ATPase with chaperone activity', 'Predicted ATP-dependent protease')
# 	COG0542_COG1067	('ATP-dependent Clp protease ATP-binding subunit ClpA', 'Predicted ATP-dependent protease')
# 	COG3480	Predicted secreted protein containing a PDZ domain
# 	COG1067_COG1672	('Predicted ATP-dependent protease', 'Predicted ATPase, archaeal AAA+ ATPase superfamily')
# COG4035
# 	COG4035	Uncharacterized membrane protein
# COG4042
# 	COG4042	Energy-converting hydrogenase Eha subunit A
# COG1784
# 	COG3333	TctA family transporter
# 	COG1784	TctA family transporter
# 	0	UnCOGged
# 	COG3333_COG3618	('TctA family transporter', 'Predicted metal-dependent hydrolase, TIM-barrel fold')
# COG2034
# 	COG2034	Uncharacterized membrane protein
# COG4039
# 	COG4039	Energy-converting hydrogenase Eha subunit C
# 	0	UnCOGged
# COG4038
# 	COG4038	Energy-converting hydrogenase Eha subunit E
# COG4907
# 	COG1512	Uncharacterized membrane protein YgcG, contains a TPM-fold domain
# 	COG4907	Uncharacterized membrane protein
# 	0	UnCOGged
# COG4040
# 	0	UnCOGged
# 	COG4040	Uncharacterized membrane protein
# COG4037
# 	COG4037	Energy-converting hydrogenase Eha subunit F
# COG4036
# 	COG4036	Energy-converting hydrogenase Eha subunit G
# COG4041
# 	COG4041	Energy-converting hydrogenase Eha subunit B
# COG4078
# 	COG1009_COG1638	('NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit', 'TRAP-type C4-dicarboxylate transport system, periplasmic component')
# 	COG1009_COG2111_COG2111	('NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit')
# 	COG1009	NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit
# 	COG1008	NADH:ubiquinone oxidoreductase subunit 4 (chain M)
# 	COG1009_COG2111	('NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit', 'Multisubunit Na+/H+ antiporter, MnhB subunit')
# COG1933
# 	COG1933	Archaeal DNA polymerase II, large subunit
# 	COG0143	Methionyl-tRNA synthetase
# 	COG1372_COG1933_COG1933	('Intein/homing endonuclease', 'Archaeal DNA polymerase II, large subunit', 'Archaeal DNA polymerase II, large subunit')
# 	COG0073_COG0143	('tRNA-binding EMAP/Myf domain', 'Methionyl-tRNA synthetase')
# 	COG0073_COG0143_COG3266	('tRNA-binding EMAP/Myf domain', 'Methionyl-tRNA synthetase', 'Cell division protein DamX, binds to the septal ring, contains C-terminal SPOR domain')
# 	COG0495	Leucyl-tRNA synthetase
# 	COG1372_COG1372_COG1933_COG1933_COG1933	('Intein/homing endonuclease', 'Intein/homing endonuclease', 'Archaeal DNA polymerase II, large subunit', 'Archaeal DNA polymerase II, large subunit', 'Archaeal DNA polymerase II, large subunit')
# 	COG1933_COG1933	('Archaeal DNA polymerase II, large subunit', 'Archaeal DNA polymerase II, large subunit')
# 	COG0495_COG0495	('Leucyl-tRNA synthetase', 'Leucyl-tRNA synthetase')
# COG0650
# 	COG0650	Formate hydrogenlyase subunit 4
# 	COG1005_COG1143	('NADH:ubiquinone oxidoreductase subunit 1 (chain H)', 'Formate hydrogenlyase subunit 6/NADH:ubiquinone oxidoreductase 23 kD subunit (chain I)')
# 	COG1005_COG1005	('NADH:ubiquinone oxidoreductase subunit 1 (chain H)', 'NADH:ubiquinone oxidoreductase subunit 1 (chain H)')
# 	COG1005	NADH:ubiquinone oxidoreductase subunit 1 (chain H)
# 	COG0265_COG1005	('Periplasmic serine protease, S1-C subfamily, contain C-terminal PDZ domain', 'NADH:ubiquinone oxidoreductase subunit 1 (chain H)')
# 	COG0650_COG1009	('Formate hydrogenlyase subunit 4', 'NADH:ubiquinone oxidoreductase subunit 5 (chain L)/Multisubunit Na+/H+ antiporter, MnhA subunit')
# 	0	UnCOGged
# COG4059
# 	COG4059	Tetrahydromethanopterin S-methyltransferase, subunit E
# COG4060
# 	COG4060	Tetrahydromethanopterin S-methyltransferase, subunit D
# COG2245
# 	0	UnCOGged
# 	COG2245	Uncharacterized membrane protein
# COG4061
# 	COG4061	Tetrahydromethanopterin S-methyltransferase, subunit C
# COG0170
# 	COG4589	Predicted CDP-diglyceride synthetase/phosphatidate cytidylyltransferase
# 	COG0575	CDP-diglyceride synthetase
# 	COG0170_COG0344	('Dolichol kinase', 'Phospholipid biosynthesis protein PlsY, probable glycerol-3-phosphate acyltransferase')
# 	COG0170	Dolichol kinase
# 	COG0170_COG1836	('Dolichol kinase', 'Uncharacterized membrane protein')
# 	0	UnCOGged
# 	COG0170_COG0558	('Dolichol kinase', 'Phosphatidylglycerophosphate synthase')
# COG1456
# 	COG0294_COG1539	('Dihydropteroate synthase', 'Dihydroneopterin aldolase')
# 	COG0294	Dihydropteroate synthase
# 	COG0294_COG0801_COG1539	('Dihydropteroate synthase', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase', 'Dihydroneopterin aldolase')
# 	COG0646_COG1410_COG1410_COG2852	('Methionine synthase I (cobalamin-dependent), methyltransferase domain', 'Methionine synthase I, cobalamin-binding domain', 'Methionine synthase I, cobalamin-binding domain', 'Very-short-patch-repair endonuclease')
# 	COG0294_COG0801	('Dihydropteroate synthase', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase')
# 	COG0285_COG0294	('Folylpolyglutamate synthase/Dihydropteroate synthase', 'Dihydropteroate synthase')
# 	COG1410_COG1410_COG2852	('Methionine synthase I, cobalamin-binding domain', 'Methionine synthase I, cobalamin-binding domain', 'Very-short-patch-repair endonuclease')
# 	COG0646_COG1410	('Methionine synthase I (cobalamin-dependent), methyltransferase domain', 'Methionine synthase I, cobalamin-binding domain')
# 	COG1456	CO dehydrogenase/acetyl-CoA synthase gamma subunit (corrinoid Fe-S protein)
# 	COG1410	Methionine synthase I, cobalamin-binding domain
# 	COG1410_COG1456	('Methionine synthase I, cobalamin-binding domain', 'CO dehydrogenase/acetyl-CoA synthase gamma subunit (corrinoid Fe-S protein)')
# COG1800
# 	COG1800	Predicted transglutaminase-like protease
# 	COG1196_COG1800	('Chromosome segregation ATPase', 'Predicted transglutaminase-like protease')
# COG3872
# 	COG3872	Uncharacterized conserved protein YqhQ
# 	COG2890_COG3872	('Methylase of polypeptide chain release factors', 'Uncharacterized conserved protein YqhQ')
# 	COG3872_COG3872	('Uncharacterized conserved protein YqhQ', 'Uncharacterized conserved protein YqhQ')
# 	COG0011	Uncharacterized conserved protein YqgV, UPF0045/DUF77 family
# 	0	UnCOGged
# 	COG0517_COG3872	('CBS domain', 'Uncharacterized conserved protein YqhQ')
# COG1284
# 	COG2364	Uncharacterized membrane protein YczE
# 	0	UnCOGged
# 	COG2771	DNA-binding transcriptional regulator, CsgD family
# 	COG1284	Uncharacterized membrane-anchored protein YitT, contains DUF161 and DUF2179 domains
# 	COG4843	Uncharacterized protein YebE, UPF0316 family
# 	COG1102_COG2364	('Cytidylate kinase', 'Uncharacterized membrane protein YczE')
# 	COG0697_COG1674	('Permease of the drug/metabolite transporter (DMT) superfamily', 'DNA segregation ATPase FtsK/SpoIIIE and related proteins')
# 	COG1284_COG1284	('Uncharacterized membrane-anchored protein YitT, contains DUF161 and DUF2179 domains', 'Uncharacterized membrane-anchored protein YitT, contains DUF161 and DUF2179 domains')
# 	COG1284_COG1418	('Uncharacterized membrane-anchored protein YitT, contains DUF161 and DUF2179 domains', 'HD superfamily phosphodieaserase, includes HD domain of RNase Y')
# COG4743
# 	COG1472_COG3507_COG5492	('Periplasmic beta-glucosidase and related glycosidases', 'Beta-xylosidase', 'Uncharacterized conserved protein YjdB, contains Ig-like domain')
# 	COG1472_COG1680	('Periplasmic beta-glucosidase and related glycosidases', 'CubicO group peptidase, beta-lactamase class C family')
# 	COG0486_COG1472	('tRNA U34 5-carboxymethylaminomethyl modifying GTPase MnmE/TrmE', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1472_COG2265	('Periplasmic beta-glucosidase and related glycosidases', 'tRNA/tmRNA/rRNA uracil-C5-methylase, TrmA/RlmC/RlmD family')
# 	COG1472_COG5492	('Periplasmic beta-glucosidase and related glycosidases', 'Uncharacterized conserved protein YjdB, contains Ig-like domain')
# 	COG1472_COG2173_COG2358	('Periplasmic beta-glucosidase and related glycosidases', 'D-alanyl-D-alanine dipeptidase', 'TRAP-type uncharacterized transport system, periplasmic component')
# 	COG1470_COG1472_COG5492	('Uncharacterized membrane protein', 'Periplasmic beta-glucosidase and related glycosidases', 'Uncharacterized conserved protein YjdB, contains Ig-like domain')
# 	COG1472_COG1472	('Periplasmic beta-glucosidase and related glycosidases', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1361_COG1472	('Uncharacterized conserved protein', 'Periplasmic beta-glucosidase and related glycosidases')
# 	0	UnCOGged
# 	COG1120_COG1472	('ABC-type cobalamin/Fe3+-siderophores transport system, ATPase component', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1472_COG2132	('Periplasmic beta-glucosidase and related glycosidases', 'Multicopper oxidase with three cupredoxin domains (includes cell division protein FtsP and spore coat protein CotA)')
# 	COG1472_COG3468	('Periplasmic beta-glucosidase and related glycosidases', 'Type V secretory pathway, adhesin AidA')
# 	COG1472_COG3265	('Periplasmic beta-glucosidase and related glycosidases', 'Gluconate kinase')
# 	COG1472_COG2755	('Periplasmic beta-glucosidase and related glycosidases', 'Lysophospholipase L1 or related esterase')
# 	COG1470_COG1472	('Uncharacterized membrane protein', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1472_COG2801	('Periplasmic beta-glucosidase and related glycosidases', 'Transposase InsO and inactivated derivatives')
# 	COG1472_COG2910	('Periplasmic beta-glucosidase and related glycosidases', 'Putative NADH-flavin reductase')
# 	COG1361	Uncharacterized conserved protein
# 	COG0768_COG1472	('Cell division protein FtsI/penicillin-binding protein 2', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1472_COG3876_COG5492	('Periplasmic beta-glucosidase and related glycosidases', 'Uncharacterized conserved protein YbbC, DUF1343 family', 'Uncharacterized conserved protein YjdB, contains Ig-like domain')
# 	COG1472_COG2890	('Periplasmic beta-glucosidase and related glycosidases', 'Methylase of polypeptide chain release factors')
# 	COG1472	Periplasmic beta-glucosidase and related glycosidases
# 	COG1472_COG5520	('Periplasmic beta-glucosidase and related glycosidases', 'O-Glycosyl hydrolase')
# 	COG0409_COG1472	('Hydrogenase maturation factor', 'Periplasmic beta-glucosidase and related glycosidases')
# 	COG1472_COG1572	('Periplasmic beta-glucosidase and related glycosidases', 'Serine protease, subtilase family')
# 	COG0115_COG1472	('Branched-chain amino acid aminotransferase/4-amino-4-deoxychorismate lyase', 'Periplasmic beta-glucosidase and related glycosidases')
# COG1916
# 	COG1263_COG1916	('Phosphotransferase system IIC components, glucose/maltose/N-acetylglucosamine-specific', 'Pheromone shutdown protein TraB, contains GTxH motif (function unknown)')
# 	COG1916_COG1916	('Pheromone shutdown protein TraB, contains GTxH motif (function unknown)', 'Pheromone shutdown protein TraB, contains GTxH motif (function unknown)')
# 	COG1670_COG3735	('Protein N-acetyltransferase, RimJ/RimL family', 'Uncharacterized conserved protein YbaP, TraB family')
# 	COG3170_COG3552	('Tfp pilus assembly protein FimV', 'Uncharacterized conserved protein, contains von Willebrand factor type A (vWA) domain')
# 	COG3552	Uncharacterized conserved protein, contains von Willebrand factor type A (vWA) domain
# 	COG0265_COG3016	('Periplasmic serine protease, S1-C subfamily, contain C-terminal PDZ domain', 'Uncharacterized iron-regulated protein')
# 	COG2304	Secreted protein containing bacterial Ig-like domain and vWFA domain
# 	COG3735	Uncharacterized conserved protein YbaP, TraB family
# 	COG1916	Pheromone shutdown protein TraB, contains GTxH motif (function unknown)
# 	COG2425	Uncharacterized protein, contains a von Willebrand factor type A (vWA) domain
# 	0	UnCOGged

# %%
cog = "COG4720"
print("Processing "+cog)
sample = list(map(lambda x: fetch_seq(x, label=cog), cogdb[cogdb[6]==cog].sample(1).index))
os.makedirs(cog, exist_ok=True)
SeqIO.write(sample, "{}/{}_query.fasta".format(cog, cog), "fasta")
print("\tStarting PSI-BLAST...")
cline = NcbipsiblastCommandline(
    query="{}/{}_query.fasta".format(cog, cog),
    db="711proteomes",
    outfmt=5,
    out="{}/{}_results.xml".format(cog, cog),
    evalue=evalt,
    max_target_seqs=5000,
    num_iterations=psi_iter,
    out_pssm="{}/{}_pssm.txt".format(cog, cog),
    num_threads=3
)
cline()
print("\tPSI-BLAST done!")

records = list(SearchIO.parse("{}/{}_results.xml".format(cog, cog), "blast-xml"))
results = rename_rec(cogdb, records[-1])
SeqIO.write(results, "results/{}_results.fasta".format(cog, cog), "fasta")
# Out:
# Processing COG4720
# 	Starting PSI-BLAST...
# 	PSI-BLAST done!
# 639

# %%
names = pd.read_table("/home/ilbumi/united_data_lib/cog/cognames2003-2014.tab", index_col=0)


def name_cogs(s):
    res = []
    for cog in s:
        if cog == '0':
            sr = ("UnCOGged")
        elif "_" in cog:
            sr = tuple(map(lambda x: names.loc[x]["name"], cog.split("_")))
        else:
            sr = (names.loc[cog]["name"])
        res.append(sr)
    return list(zip(s, res))
 
    
for k, v in found_cogs.items():
    print(k)
    found_names = name_cogs(v)
    for name in found_names:
        print("\t{}\t{}".format(*name))
# Out:
# /home/ilbumi/anaconda3/envs/sci/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# COG4720
# 	0	UnCOGged
# 	COG2202_COG3275_COG5002	('PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase')
# 	COG4191_COG4251	('Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG2199	GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants
# 	COG2199_COG2202_COG2206_COG3275	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'PAS domain', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family')
# 	COG3275	Sensor histidine kinase, LytS/YehU family
# 	COG0784_COG4191_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2202_COG3852	('PAS domain', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG0784_COG2202_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0697	Permease of the drug/metabolite transporter (DMT) superfamily
# 	COG0784_COG2205_COG3275	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD', 'Sensor histidine kinase, LytS/YehU family')
# 	COG3275_COG3829_COG5002	('Sensor histidine kinase, LytS/YehU family', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase')
# 	COG3275_COG4191	('Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG3437	Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains
# 	COG3275_COG5001	('Sensor histidine kinase, LytS/YehU family', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG5002	Signal transduction histidine kinase
# 	COG1263_COG3829_COG3852	('Phosphotransferase system IIC components, glucose/maltose/N-acetylglucosamine-specific', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG0745_COG3447_COG3614_COG5002	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'Integral membrane sensor domain MASE1', 'Extracellular (periplasmic) sensor domain CHASE1 (specificity unknown)', 'Signal transduction histidine kinase')
# 	COG0745_COG0784_COG2198_COG2205_COG3829_COG3850	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase, nitrate/nitrite-specific')
# 	COG0784_COG2202_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD')
# 	COG4191	Signal transduction histidine kinase regulating C4-dicarboxylate transport system
# 	COG2204_COG2461_COG3275_COG4191	('DNA-binding transcriptional response regulator, NtrC family, contains REC, AAA-type ATPase, and a Fis-type DNA-binding domains', 'Uncharacterized conserved protein, DUF438 domain, may contain hemerythrin domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG4251	Bacteriophytochrome (light-regulated signal transduction histidine kinase)
# 	COG0619_COG1122_COG1122	('Energy-coupling factor transporter transmembrane protein EcfT', 'Energy-coupling factor transporter ATP-binding protein EcfA2', 'Energy-coupling factor transporter ATP-binding protein EcfA2')
# 	COG3275_COG3437	('Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG0745_COG0784_COG2198_COG2202_COG2205_COG4720	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Uncharacterized membrane protein')
# 	COG0310_COG2202_COG2202_COG3829_COG4251	('ABC-type Co2+ transport system, permease component', 'PAS domain', 'PAS domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG2202_COG3275_COG5001	('PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG3706_COG3829	('Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG3290_COG3437	('Sensor histidine kinase regulating citrate/malate metabolism', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG2203_COG3706_COG3829	('GAF domain', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG1122_COG1122_COG4720	('Energy-coupling factor transporter ATP-binding protein EcfA2', 'Energy-coupling factor transporter ATP-binding protein EcfA2', 'Uncharacterized membrane protein')
# 	COG0745_COG4191	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0784_COG4191_COG5002	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase')
# 	COG2199_COG2200	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'EAL domain, c-di-GMP-specific phosphodiesterase class I (or its enzymatically inactive variant)')
# 	COG0419_COG1842_COG5412_COG5412	('DNA repair exonuclease SbcCD ATPase subunit', 'Phage shock protein A', 'Phage-related protein', 'Phage-related protein')
# 	COG0310_COG0619_COG1930	('ABC-type Co2+ transport system, permease component', 'Energy-coupling factor transporter transmembrane protein EcfT', 'ABC-type cobalt transport system, periplasmic component')
# 	COG2206_COG3275_COG3292_COG3292	('HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family', 'Periplasmic ligand-binding sensor domain', 'Periplasmic ligand-binding sensor domain')
# 	COG0784_COG0784_COG2198_COG2202_COG2205_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2208_COG3275	('Serine phosphatase RsbU, regulator of sigma subunit', 'Sensor histidine kinase, LytS/YehU family')
# 	COG4191_COG5002	('Signal transduction histidine kinase regulating C4-dicarboxylate transport system', 'Signal transduction histidine kinase')
# 	COG1914_COG3275	('Mn2+ and Fe2+ transporters of the NRAMP family', 'Sensor histidine kinase, LytS/YehU family')
# 	COG2203_COG2203_COG3275_COG3437	('GAF domain', 'GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG5000	Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation
# 	COG2206	HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)
# 	COG0784_COG2202_COG2203_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'GAF domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2203_COG3706	('GAF domain', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain')
# 	COG2199_COG3275_COG3437	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'Sensor histidine kinase, LytS/YehU family', 'Response regulator c-di-GMP phosphodiesterase, RpfG family, contains REC and HD-GYP domains')
# 	COG0784_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG2199_COG2206	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)')
# 	COG2208_COG2770_COG4720	('Serine phosphatase RsbU, regulator of sigma subunit', 'HAMP domain', 'Uncharacterized membrane protein')
# 	COG0310	ABC-type Co2+ transport system, permease component
# 	COG2203_COG3275_COG4251	('GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG2891	Cell shape-determining protein MreD
# 	COG0340_COG1268	('Biotin-(acetyl-CoA carboxylase) ligase', 'Biotin transporter BioY')
# 	COG0784_COG2198_COG5002	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Signal transduction histidine kinase')
# 	COG0745_COG2202_COG2205_COG4191	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'PAS domain', 'K+-sensing histidine kinase KdpD', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG3275_COG3275	('Sensor histidine kinase, LytS/YehU family', 'Sensor histidine kinase, LytS/YehU family')
# 	COG0697_COG0784_COG2198_COG5000_COG5002	('Permease of the drug/metabolite transporter (DMT) superfamily', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Signal transduction histidine kinase involved in nitrogen fixation and metabolism regulation', 'Signal transduction histidine kinase')
# 	COG1172_COG1672	('Ribose/xylose/arabinose/galactoside ABC-type transport system, permease component', 'Predicted ATPase, archaeal AAA+ ATPase superfamily')
# 	COG0642_COG0784_COG2202	('Signal transduction histidine kinase', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain')
# 	COG1122_COG1122	('Energy-coupling factor transporter ATP-binding protein EcfA2', 'Energy-coupling factor transporter ATP-binding protein EcfA2')
# 	COG5001	Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain
# 	COG4732	Predicted membrane protein
# 	COG0395_COG3829_COG5001_COG5002	('ABC-type glycerol-3-phosphate transport system, permease component', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain', 'Signal transduction histidine kinase')
# 	COG2205_COG3275	('K+-sensing histidine kinase KdpD', 'Sensor histidine kinase, LytS/YehU family')
# 	COG3859	Thiamine transporter ThiT
# 	COG2199_COG2206_COG3275	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family')
# 	COG2200	EAL domain, c-di-GMP-specific phosphodiesterase class I (or its enzymatically inactive variant)
# 	COG0784_COG0784_COG2198_COG2202_COG2203_COG2205_COG3829_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'PAS domain', 'GAF domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG3275_COG3706	('Sensor histidine kinase, LytS/YehU family', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain')
# 	COG3601	Riboflavin transporter FmnP
# 	COG2199_COG2202	('GGDEF domain, diguanylate cyclase (c-di-GMP synthetase) or its enzymatically inactive variants', 'PAS domain')
# 	COG2202_COG2202_COG5001	('PAS domain', 'PAS domain', 'Predicted signal transduction protein containing a membrane domain, an EAL and a GGDEF domain')
# 	COG0697_COG4172	('Permease of the drug/metabolite transporter (DMT) superfamily', 'ABC-type microcin C transport system, duplicated ATPase component YejF')
# 	COG2205_COG3829_COG3829	('K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG4684	Uncharacterized membrane protein
# 	COG0784_COG2205_COG3447	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD', 'Integral membrane sensor domain MASE1')
# 	COG3829_COG4251	('Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG3275_COG3706_COG5002	('Sensor histidine kinase, LytS/YehU family', 'Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain', 'Signal transduction histidine kinase')
# 	COG2205	K+-sensing histidine kinase KdpD
# 	COG0784_COG2205_COG3829	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'K+-sensing histidine kinase KdpD', 'Transcriptional regulator containing PAS, AAA-type ATPase, and DNA-binding Fis domains')
# 	COG0310_COG0619	('ABC-type Co2+ transport system, permease component', 'Energy-coupling factor transporter transmembrane protein EcfT')
# 	COG0784_COG2202_COG2203_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'PAS domain', 'GAF domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0745_COG2202_COG2202_COG3275_COG3852	('DNA-binding response regulator, OmpR family, contains REC and winged-helix (wHTH) domain', 'PAS domain', 'PAS domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase, nitrogen specific')
# 	COG2202_COG2202_COG4251	('PAS domain', 'PAS domain', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG0784_COG2197_COG2202_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'DNA-binding response regulator, NarL/FixJ family, contains REC and HTH domains', 'PAS domain', 'K+-sensing histidine kinase KdpD')
# 	COG2206_COG3275	('HD-GYP domain, c-di-GMP phosphodiesterase class II (or its inactivated variant)', 'Sensor histidine kinase, LytS/YehU family')
# 	COG3706	Two-component response regulator, PleD family, consists of two REC domains and a diguanylate cyclase (GGDEF) domain
# 	COG0784_COG2198_COG3275_COG4251	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'Sensor histidine kinase, LytS/YehU family', 'Bacteriophytochrome (light-regulated signal transduction histidine kinase)')
# 	COG0784_COG2198_COG2205	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'HPt (histidine-containing phosphotransfer) domain', 'K+-sensing histidine kinase KdpD')
# 	COG2202_COG2202_COG5002_COG5002	('PAS domain', 'PAS domain', 'Signal transduction histidine kinase', 'Signal transduction histidine kinase')
# 	COG3850_COG4191	('Signal transduction histidine kinase, nitrate/nitrite-specific', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG4720	Uncharacterized membrane protein
# 	COG0784_COG3275_COG4191	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'Sensor histidine kinase, LytS/YehU family', 'Signal transduction histidine kinase regulating C4-dicarboxylate transport system')
# 	COG0784_COG2203_COG2205_COG3447	('CheY chemotaxis protein or a CheY-like REC (receiver) domain', 'GAF domain', 'K+-sensing histidine kinase KdpD', 'Integral membrane sensor domain MASE1')
# 	COG2208	Serine phosphatase RsbU, regulator of sigma subunit
